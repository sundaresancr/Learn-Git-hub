# %%
print("Hello World")
# Out:
# Hello World

# %%
# Set the backend as the screen output
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pylab as pl

# %%
plt.plot([1.5,3.0])

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])

# %%
fig, ax = plt.subplots() # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]) # Plot some data on the axes.

# %%
plt.title("Learning Matplotlib")
# Out:
# Text(0.5, 1.0, 'Learning Matplotlib')

# %%
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.ioff()

# %%
matplotlib.is_interactive()
# Out:
# False

# %%
plt.plot(([1.6,3.0]))

# %%
plt.title("Non interactive plot")
# Out:
# Text(0.5, 1.0, 'Non interactive plot')

# %%
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
plt.show()

# %% [markdown]
# # Exercices from https://www.w3resource.com/graphics/matplotlib/index.php

# %% [markdown]
# Matplotlib Basic

# %% [markdown]
# 1. Write a Python program to draw a line with suitable label in the x axis, y axis and a title. Go to the editor
# The code snippet gives the output shown in the following screenshot:

# %%
x = np.arange(0,50,10)
y = [value * 3 for value in x]
#y = 3*x # output is same as y = [value * 3 for value in x]
plt.plot(x, y)
plt.title( 'Example1')
plt.xlabel(' x axis')
plt.ylabel(' y axis')
plt.arrow(10,60,5.0,5.0)

# %% [markdown]
# 2. Write a Python program to draw a line using given axis values with suitable label in the x axis , y axis and a title. Go to the editor

# %%
x2 = [1.0,2.0,3.0]
y2 = [2.0,4.0,1.0]
plt.plot(x2,y2)
plt.xlabel('x axis')
plt.ylabel('yaxis')
plt.title("Practice Matplotlib Excercise 2")
plt.grid(True)

# %% [markdown]
# 3. Write a Python program to draw a line using given axis values taken from a text file, with suitable label in the x axis, y axis and a title. Go to the editor
# Test Data:
# test.txt
# 1 2
# 2 4
# 3 1
# The code snippet gives the output shown in the following screenshot:

# %%
x3 = [1,2,3]
y3 = [2,4,1]

plt.plot(x3,y3)
plt.title("Matplob lib practice ex3")
plt.xlabel(" X axis")
plt.ylabel(" Y axis")
plt.grid()

# %% [markdown]
# 4. Write a Python program to draw line charts of the financial data of Alphabet Inc. between October 3, 2016 to October 7, 2016. Go to the editor
# Sample Financial data (fdata.csv):
# Date,Open,High,Low,Close
# 10-03-16,774.25,776.065002,769.5,772.559998
# 10-04-16,776.030029,778.710022,772.890015,776.429993
# 10-05-16,779.309998,782.070007,775.650024,776.469971
# 10-06-16,779,780.47998,775.539978,776.859985
# 10-07-16,779.659973,779.659973,770.75,775.080017

# %%
# not double backslsh\\ , copy file path from file eplorer and add \

df_mpl1 = pd.read_csv('C:\\Users\\Sundaresan C R\\fdata.csv',sep=',', parse_dates=True, index_col=0)
df_mpl1
# Out:
#                   Open        High         Low       Close
# Date
# 2016-10-03  774.250000  776.065002  769.500000  772.559998
# 2016-10-04  776.030029  778.710022  772.890015  776.429993
# 2016-10-05  779.309998  782.070007  775.650024  776.469971
# 2016-10-06  779.000000  780.479980  775.539978  776.859985
# 2016-10-07  779.659973  779.659973  770.750000  775.080017

# %%
#df_mpl1['Open']
#df_mpl1['Date']

df_mpl1.plot()

#plt.plot(df_mpl1[Open])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
matplotlib.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
#matplotlib.interactive(b)
matplotlib.is_interactive()
# Out:
# False

# %%
matplotlib.get_cachedir()
# Out:
# 'C:\\Users\\Sundaresan C R\\.matplotlib'

# %% [markdown]
# 5. Write a Python program to plot two or more lines on same plot with suitable legends of each line. Go to the editor
# The code snippet gives the output shown in the following screenshot:

# %%
x1=[10,20,30]
y1=[20,40,10]
plt.plot(x1,y1,label = "Line1")

x2=[10,20,30]
y1=[40,10,30]
plt.plot(x1,y1,label = "Line2")
plt.legend()
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title('Two or more lines on same plot with suitable legends ')
# Out:
# Text(0.5, 1.0, 'Two or more lines on same plot with suitable legends ')

# %% [markdown]
# 6. Write a Python program to plot two or more lines with legends, different widths and colors. Go to the editor
# The code snippet gives the output shown in the following screenshot:

# %%
x6_1 = [10,20,30]
y6_1 = [20,40,10]

x6_2 = [10,20,30]
y6_2 = [40,10,30]

plt.plot(x6_1,y6_1, label = "Line1",color = 'red', linewidth=5.0)
plt.plot(x6_2,y6_2,label = "line2", color = 'blue',linewidth=5.0)

plt.legend()
plt.title('Two or more thick lines on same plot with suitable legends ')
# Out:
# Text(0.5, 1.0, 'Two or more thick lines on same plot with suitable legends ')

# %% [markdown]
# 7. Write a Python program to plot two or more lines with different styles. Go to the editor
# The code snippet gives the output shown in the following screenshot:
#
# Matplotlib Basic: Plot two or more lines with different styles

# %%
x7_1 = [10,20,30]
y7_1 = [20,40,10]

x7_2 = [0,20,30]
y7_2 = [40,10,30]

plt.plot(x7_1,y7_1,label = "Line1",color = 'red', linewidth=5.0, linestyle = 'dotted' )


plt.plot(x7_2,y7_2,label = "Line1",color = 'blue', linewidth=5.0, linestyle = 'dashed' )


plt.bar(x7_2,y7_2,label = "Line1",color = 'blue', linewidth=5.0, linestyle = 'dashed' )
# Out:
# <BarContainer object of 3 artists>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-8b4eee6cbc1b> in <module>
# ----> 1 Axes.plot
#
# NameError: name 'Axes' is not defined

# %% [markdown]
# 9. Write a Python program to display the current axis limits values and set new axis values. Go to the editor
# The code snippet gives the output shown in the following screenshot:

# %%
x9_1 = [0,50]
y9_1 = [0,150]

plt.plot(x9_1,y9_1)
# shows the current axis limits values
plt.axis()
# set new axes limits
plt.axis([0, 100, 0, 200])
# Out:
# (0.0, 100.0, 0.0, 200.0)

# %% [markdown]
# 10. Write a Python program to plot quantities which have an x and y position.

# %% [markdown]
#  10. Write a Python program to plot quantities which have an x and y position.

# %%
x10_1 = [2, 3, 5, 6, 8]
y10_1 = [1, 5, 10, 18, 20]

x10_2 = [3, 4, 6, 7, 9]
y10_2 = [2, 6, 11, 20, 22]

plt.plot(x10_1, y10_1, 'bo')
plt.plot(x10_2,y10_2,'.r')

# %% [markdown]
# 11. Write a Python program to plot several lines with different format styles in one command using arrays.

# %%
x10_1 = [2, 3, 5, 6, 8]

# it is not poosible to square elements of the list  lik y10_1 = x10_1**2, need to convert to array , square and then convert 
#to list t = np.arange(0., 5., 0.2)

array_x10_1 = np.array(x10_1)

array_y10_1 = array_x10_1**2

array_z10_1 = array_x10_1**2

plt.plot(array_x10_1,array_x10_1,'4g')

plt.plot(array_x10_1,array_x10_1**2,'ko')

#plt.plot(array_y10_1,array_y10_1**3,'ko')

# %%
plt.subplots(ncols=2, nrows=2, constrained_layout=True)
# Out:
# (<Figure size 432x288 with 4 Axes>,
#  array([[<AxesSubplot:>, <AxesSubplot:>],
#         [<AxesSubplot:>, <AxesSubplot:>]], dtype=object))

# %% [markdown]
# # Bar chart

# %%
fig , ax = plt.subplots(nrows=2,ncols=2)
print(ax)
# Out:
# [[<AxesSubplot:> <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:>]]

# %%
fig = plt.gcf()
ax = plt.gca()

# %%
fig , (ax1,ax2) = plt.subplots(nrows=2,ncols=2)
print(ax1)
print(ax2)
# Out:
# [<AxesSubplot:> <AxesSubplot:>]
# [<AxesSubplot:> <AxesSubplot:>]

# %% [markdown]
# 1 Write a Python programming to display a bar chart of the popularity of programming Languages

# %%
Prog_lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'] 
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

Subject = ['science','Maths','History','Geography','English','Tamil'] 

fig , (ax1,ax2) = plt.subplots(2,1)
print(ax)

ax1.bar(Prog_lang,popularity)
ax2.bar(Subject,popularity)
#ax3.bar(Prog_lang,popularity)
#ax4.bar(Subject,popularity)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# <BarContainer object of 6 artists>

# %% [markdown]
# 2.Write a Python programming to display a bar chart of the popularity of programming Languages

# %%
fig , ax5 = plt.subplots(1,1)
ax5.barh(Prog_lang,popularity)
#ax2.barh(Subject,popularity)
plt.show()

# %% [markdown]
# # PIE chart

# %%
popularity1 = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
Prog_lang5 = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
fig5, ax5 = plt.subplots()
ax5.pie(popularity1, labels = Prog_lang5 )
# Out:
# ([<matplotlib.patches.Wedge at 0x1fb08f147c0>,
# ...
#  [Text(0.6106212455488447, 0.914954476727874, 'Java'),
#   Text(-1.0139237282141302, 0.42656614184011216, 'Python'),
#   Text(-0.7897694469856671, -0.7656789278855424, 'PHP'),
#   Text(-0.06323929665114071, -1.0981806733680344, 'JavaScript'),
#   Text(0.654413852726294, -0.8841620379545417, 'C#'),
#   Text(1.0520142924916651, -0.3213501647630839, 'C++')])

# %%
#import matplotlib.pyplot as plt
a1 = plt.subplot2grid((3,3),(0,0),colspan = 2)
a2 = plt.subplot2grid((3,3),(0,2), rowspan = 3)
a3 = plt.subplot2grid((3,3),(1,0),rowspan = 2, colspan = 2)
import numpy as np
x = np.arange(1,10)
a2.plot(x, x*x)
a2.set_title('square')
a1.plot(x, np.exp(x))
a1.set_title('exp')
a3.plot(x, np.log(x))
a3.set_title('log')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Chapter 12: Using axisartist Toolkit

# %%
matplotlib.use
# Out:
# <function matplotlib.use(backend, *, force=True)>

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...
